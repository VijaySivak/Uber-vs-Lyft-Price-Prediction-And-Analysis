# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant
from tqdm import tqdm
from sklearn.metrics import r2_score
from sklearn.linear_model import Lasso, Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.metrics import f1_score
from scipy.stats import probplot
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV
from xgboost import XGBRegressor

df = pd.read_csv('/Users/vijaysivakumar/Desktop/Projects/Uber_Lyft/rideshare_kaggle.csv')

# %matplotlib inline

# %%
df.shape
# Out:
# (693071, 57)

# %%
df.head()
df['price']
# Out:
# 0          5.0
# 1         11.0
# 2          7.0
# 3         26.0
# 4          9.0
#           ...
# 693066    13.0
# 693067     9.5
# 693068     NaN
# 693069    27.0
# 693070    10.0
# Name: price, Length: 693071, dtype: float64

# %% [markdown]
# # Data Cleaning

# %%
df.isnull().sum()
# Out:
# id                                 0
# timestamp                          0
# hour                               0
# day                                0
# month                              0
# datetime                           0
# timezone                           0
# source                             0
# destination                        0
# cab_type                           0
# product_id                         0
# name                               0
# price                          55095
# distance                           0
# surge_multiplier                   0
# latitude                           0
# longitude                          0
# temperature                        0
# apparentTemperature                0
# short_summary                      0
# long_summary                       0
# precipIntensity                    0
# precipProbability                  0
# humidity                           0
# windSpeed                          0
# windGust                           0
# windGustTime                       0
# visibility                         0
# temperatureHigh                    0
# temperatureHighTime                0
# temperatureLow                     0
# temperatureLowTime                 0
# apparentTemperatureHigh            0
# apparentTemperatureHighTime        0
# apparentTemperatureLow             0
# apparentTemperatureLowTime         0
# icon                               0
# dewPoint                           0
# pressure                           0
# windBearing                        0
# cloudCover                         0
# uvIndex                            0
# visibility.1                       0
# ozone                              0
# sunriseTime                        0
# sunsetTime                         0
# moonPhase                          0
# precipIntensityMax                 0
# uvIndexTime                        0
# temperatureMin                     0
# temperatureMinTime                 0
# temperatureMax                     0
# temperatureMaxTime                 0
# apparentTemperatureMin             0
# apparentTemperatureMinTime         0
# apparentTemperatureMax             0
# apparentTemperatureMaxTime         0
# dtype: int64

# %%
df.dropna(axis=0,inplace=True)

# %%
df.isnull().sum()
# Out:
# id                             0
# timestamp                      0
# hour                           0
# day                            0
# month                          0
# datetime                       0
# timezone                       0
# source                         0
# destination                    0
# cab_type                       0
# product_id                     0
# name                           0
# price                          0
# distance                       0
# surge_multiplier               0
# latitude                       0
# longitude                      0
# temperature                    0
# apparentTemperature            0
# short_summary                  0
# long_summary                   0
# precipIntensity                0
# precipProbability              0
# humidity                       0
# windSpeed                      0
# windGust                       0
# windGustTime                   0
# visibility                     0
# temperatureHigh                0
# temperatureHighTime            0
# temperatureLow                 0
# temperatureLowTime             0
# apparentTemperatureHigh        0
# apparentTemperatureHighTime    0
# apparentTemperatureLow         0
# apparentTemperatureLowTime     0
# icon                           0
# dewPoint                       0
# pressure                       0
# windBearing                    0
# cloudCover                     0
# uvIndex                        0
# visibility.1                   0
# ozone                          0
# sunriseTime                    0
# sunsetTime                     0
# moonPhase                      0
# precipIntensityMax             0
# uvIndexTime                    0
# temperatureMin                 0
# temperatureMinTime             0
# temperatureMax                 0
# temperatureMaxTime             0
# apparentTemperatureMin         0
# apparentTemperatureMinTime     0
# apparentTemperatureMax         0
# apparentTemperatureMaxTime     0
# dtype: int64

# %%
duplicateRows = df[df.duplicated()]
duplicateRows
# Out:
# Empty DataFrame
# Columns: [id, timestamp, hour, day, month, datetime, timezone, source, destination, cab_type, product_id, name, price, distance, surge_multiplier, latitude, longitude, temperature, apparentTemperature, short_summary, long_summary, precipIntensity, precipProbability, humidity, windSpeed, windGust, windGustTime, visibility, temperatureHigh, temperatureHighTime, temperatureLow, temperatureLowTime, apparentTemperatureHigh, apparentTemperatureHighTime, apparentTemperatureLow, apparentTemperatureLowTime, icon, dewPoint, pressure, windBearing, cloudCover, uvIndex, visibility.1, ozone, sunriseTime, sunsetTime, moonPhase, precipIntensityMax, uvIndexTime, temperatureMin, temperatureMinTime, temperatureMax, temperatureMaxTime, apparentTemperatureMin, apparentTemperatureMinTime, apparentTemperatureMax, apparentTemperatureMaxTime]
# Index: []
#
# [0 rows x 57 columns]

# %% [markdown]
# **Calculating VIF for feature selection**:

# %%
# og_cols  = [i for i in df.columns]

# Adding a constant for VIF calculation
X = add_constant(df.select_dtypes(include=[np.number]).dropna())

# Calculating VIF for each feature
vif_data = pd.DataFrame()
vif_data['feature'] = X.columns
vif_data['VIF'] = [variance_inflation_factor(X.values, i) for i in tqdm(range(X.shape[1]))]

# Display the VIF data
print(vif_data)
# Out:
#   0%|          | 0/47 [00:00<?, ?it/s]/Users/vijaysivakumar/Desktop/Projects/Uber_Lyft/venv/lib/python3.13/site-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# 100%|██████████| 47/47 [00:43<00:00,  1.09it/s]
#                         feature           VIF
# 0                         const  0.000000e+00
# 1                     timestamp  4.447783e+05
# 2                          hour  5.900773e+02
# 3                           day  6.981158e+05
# 4                         month  1.528996e+06
# 5                         price  1.208808e+00
# 6                      distance  1.139914e+00
# 7              surge_multiplier  1.065698e+00
# 8                      latitude  6.511429e+00
# 9                     longitude  2.347308e+00
# 10                  temperature  6.892170e+02
# 11          apparentTemperature  1.155553e+02
# 12              precipIntensity  5.208862e+00
# 13            precipProbability  6.961462e+00
# 14                     humidity  2.816832e+02
# 15                    windSpeed  2.767699e+01
# 16                     windGust  1.686844e+01
# 17                 windGustTime  2.034360e+04
# 18                   visibility  9.382499e+13
# 19              temperatureHigh  1.086686e+05
# 20          temperatureHighTime  2.282395e+05
# 21               temperatureLow  2.988979e+02
# 22           temperatureLowTime  9.466792e+04
# 23      apparentTemperatureHigh  4.736869e+04
# 24  apparentTemperatureHighTime  9.516888e+05
# 25       apparentTemperatureLow  1.639396e+02
# 26   apparentTemperatureLowTime  1.287520e+05
# 27                     dewPoint  9.611239e+02
# 28                     pressure  2.560824e+01
# 29                  windBearing  3.535974e+00
# 30                   cloudCover  2.672954e+00
# 31                      uvIndex  1.465318e+00
# 32                 visibility.1  1.501200e+15
# 33                        ozone  1.136975e+01
# 34                  sunriseTime  5.331827e+09
# 35                   sunsetTime  5.411722e+09
# 36                    moonPhase  8.326300e+01
# 37           precipIntensityMax  3.433169e+01
# 38                  uvIndexTime  1.900363e+06
# 39               temperatureMin  1.210941e+02
# 40           temperatureMinTime  3.498111e+04
# 41               temperatureMax  9.459075e+04
# 42           temperatureMaxTime  3.233111e+04
# 43       apparentTemperatureMin  1.958019e+02
# 44   apparentTemperatureMinTime  3.438187e+04
# 45       apparentTemperatureMax  3.876692e+04
# 46   apparentTemperatureMaxTime  9.010047e+05

# %%
vif_data = df[["price", "distance", "surge_multiplier", "latitude", "longitude", "precipIntensity", "precipProbability", "windBearing" ,"cloudCover", "cab_type", "name" ]]

vif_data['price'].shape
# Out:
# (637976,)

# %%
df['visibility'].equals(df['visibility.1'])
#Checking for duplicate columns
# Out:
# True

# %%
df = df.drop(['visibility.1'],axis=1)
#Dropping the duplicate columns

# %%
# df.info()

item_counts = df["month"].value_counts()
item_counts
# Out:
# month
# 12    374205
# 11    263771
# Name: count, dtype: int64

# %%
df['datetime']=pd.to_datetime(df['datetime'])
df.shape
# Out:
# (637976, 56)

# %% [markdown]
# ### **Exploratory data analysis**

# %%
rideshare_df = df
# Convert timestamp to datetime
rideshare_df['timestamp'] = pd.to_datetime(rideshare_df['timestamp'], unit='s')

# Extract hour from timestamp
rideshare_df['hour'] = rideshare_df['timestamp'].dt.hour

# Calculate the average price for each hour
average_price_by_hour = rideshare_df.groupby('hour')['price'].mean()

# Plot the average price against every hour
plt.figure(figsize=(12, 6))
plt.plot(average_price_by_hour.index, average_price_by_hour.values, marker='o', linestyle='-')
plt.title('Average Price by Hour')
plt.xlabel('Hour of the Day')
plt.ylabel('Average Price')
plt.xticks(range(24))
plt.grid(True)
plt.show()

# %%
# The line graph above illustrates the count of different surge multipliers for Lyft rides across various times of the day. Each surge multiplier category is represented by a different line,
## showing its frequency during morning, afternoon, evening, and night.
shared_rides = df[df['name'].str.contains('Shared', case=False)]
lyft_data = df[df['cab_type'] == 'Lyft']

def assign_time_of_day(hour):
    if 6 <= hour < 12:
        return 'Morning'
    elif 12 <= hour < 15:
        return 'Afternoon'
    elif 15 <= hour < 18:
        return 'Evening'
    else:
        return 'Night'

lyft_data['Time of Day'] = lyft_data['hour'].apply(assign_time_of_day)

surge_counts = lyft_data.groupby(['Time of Day', 'surge_multiplier']).size().reset_index(name='Count')
surge_counts['Surge'] = surge_counts['surge_multiplier'].apply(lambda x: 'Surge ' + str(x))

plt.figure(figsize=(12, 8))
sns.lineplot(x='Time of Day', y='Count', hue='Surge', data=surge_counts).set_title('Time of Day wise Surge for Lyft')
plt.show()

##The line graph now only includes instances where the surge multiplier was greater than one for Lyft rides,
# providing a clearer view of the surge pricing trends excluding the base fare times.

surge_counts_filtered = surge_counts[surge_counts['surge_multiplier'] != 1]

# Plotting the line graph for Lyft cab type data with surge multiplier values not equal to 1
plt.figure(figsize=(12, 8))
sns.lineplot(x='Time of Day', y='Count', hue='Surge', data=surge_counts_filtered).set_title('Time of Day wise Surge for Lyft (Excluding Surge 1)')
plt.show()

## Our understanding from the plot
'''
Interpretation:

Lyft’s Prime Timing happens the most during nighttime.
Morning rush hours also contribute to the surge.
A surge is less likely to happen during the afternoon and evening.'''

################################################################################################

# Plotting the line graph of price vs distance with lines indicating Uber and Lyft separately
plt.figure(figsize=(12, 8))
sns.lineplot(x='distance', y='price', hue='cab_type', data=df)
plt.title('Price vs Distance for Uber and Lyft')
plt.xlabel('Distance')
plt.ylabel('Price')
plt.show()

'''
Interpretation:

Uber is riders’ first choice irrespective of distance.'''
# Out:
# /var/folders/b5/z1mdh0057vs4z278pnx74b040000gn/T/ipykernel_96302/698845136.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lyft_data['Time of Day'] = lyft_data['hour'].apply(assign_time_of_day)
# '\nInterpretation:\n\nUber is riders’ first choice irrespective of distance.'

# %%
## showing its frequency during morning, afternoon, evening, and night.
shared_rides = df[df['name'].str.contains('Shared', case=False)]
lyft_data = df[df['cab_type'] == 'Lyft']

def assign_time_of_day(hour):
    if 6 <= hour < 12:
        return 'Morning'
    elif 12 <= hour < 15:
        return 'Afternoon'
    elif 15 <= hour < 18:
        return 'Evening'
    else:
        return 'Night'

lyft_data['Time of Day'] = lyft_data['hour'].apply(assign_time_of_day)

surge_counts = lyft_data.groupby(['Time of Day', 'surge_multiplier']).size().reset_index(name='Count')
surge_counts['Surge'] = surge_counts['surge_multiplier'].apply(lambda x: 'Surge ' + str(x))

plt.figure(figsize=(12, 8))
sns.lineplot(x='Time of Day', y='Count', hue='Surge', data=surge_counts).set_title('Time of Day wise Surge for Lyft')
plt.show()

##The line graph now only includes instances where the surge multiplier was greater than one for Lyft rides,
# providing a clearer view of the surge pricing trends excluding the base fare times.

surge_counts_filtered = surge_counts[surge_counts['surge_multiplier'] != 1]

# Plotting the line graph for Lyft cab type data with surge multiplier values not equal to 1
plt.figure(figsize=(12, 8))
sns.lineplot(x='Time of Day', y='Count', hue='Surge', data=surge_counts_filtered).set_title('Time of Day wise Surge for Lyft (Excluding Surge 1)')
plt.show()

## Our understanding from the plot
'''
Interpretation:

Lyft’s Prime Timing happens the most during nighttime.
Morning rush hours also contribute to the surge.
A surge is less likely to happen during the afternoon and evening.'''

################################################################################################

# Plotting the line graph of price vs distance with lines indicating Uber and Lyft separately
plt.figure(figsize=(12, 8))
sns.lineplot(x='distance', y='price', hue='cab_type', data=df)
plt.title('Price vs Distance for Uber and Lyft')
plt.xlabel('Distance')
plt.ylabel('Price')
plt.show()

'''
Interpretation:

Uber is riders’ first choice irrespective of distance.'''


# Creating a scatterplot for shared rides with different colors indicating different times of day
plt.figure(figsize=(12, 8))
sns.scatterplot(x='distance', y='price', hue=lyft_data['Time of Day'], data=shared_rides, palette='Set2')
plt.title('Shared Ride Price vs Distance by Time of Day')
plt.xlabel('Distance (miles)')
plt.ylabel('Price (USD)')
plt.show()


'''Number of Shared Rides with Distance and Price

Interpretation:

1.People most likely have shared rides during the nighttime.
2.As the distance increases, the price also increases.
3.The number of shared rides is not growing with the increase in distance.
4.Apparently, people prefer to have shared rides for smaller distances.
People like taking shared rides over the courses of short passages, roughly lying between 1 to 3 kilometers.'''

#################################################################################################

#We can see average or mean of our price data in every route (source-destination) through table below

pd.set_option('display.max_rows', 72)
df.groupby(by=["source","destination"]).price.agg(["mean"])



shared_rides.shape
shared_rides['Time of Day'] = shared_rides['hour'].apply(assign_time_of_day)

# Creating a bar graph for the count of shared rides by time of day with the same shade of colors
plt.figure(figsize=(12, 8))
sns.countplot(y=shared_rides['Time of Day'], data=shared_rides, palette='Set2')
plt.title('Count of Shared Rides by Time of Day')
plt.ylabel('Time of Day')
plt.xlabel('Count')
plt.show()
# Out:
# /var/folders/b5/z1mdh0057vs4z278pnx74b040000gn/T/ipykernel_96302/1072014365.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lyft_data['Time of Day'] = lyft_data['hour'].apply(assign_time_of_day)
# /var/folders/b5/z1mdh0057vs4z278pnx74b040000gn/T/ipykernel_96302/1072014365.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shared_rides['Time of Day'] = shared_rides['hour'].apply(assign_time_of_day)
# /var/folders/b5/z1mdh0057vs4z278pnx74b040000gn/T/ipykernel_96302/1072014365.py:91: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=shared_rides['Time of Day'], data=shared_rides, palette='Set2')

# %%
# Calculate the distribution of Lyft and Uber rides over different sources and destinations
source_dest_distribution = rideshare_df.groupby(['source', 'destination', 'cab_type']).size().unstack()

# Display the distribution
source_dest_distribution

source_dest_distribution['Total'] = source_dest_distribution['Lyft'] + source_dest_distribution['Uber']
source_dest_distribution
# Out:
# cab_type                                         Lyft  Uber  Total
# source                  destination
# Back Bay                Boston University        4164  4518   8682
#                         Fenway                   4212  4506   8718
#                         Haymarket Square         4236  4602   8838
#                         North End                4548  4866   9414
#                         Northeastern University  4271  4554   8825
#                         South Station            4224  4500   8724
# Beacon Hill             Boston University        4098  4392   8490
#                         Fenway                   4200  4488   8688
#                         Haymarket Square         4218  4584   8802
#                         North End                4446  4794   9240
#                         Northeastern University  4302  4614   8916
#                         South Station            4200  4505   8705
# Boston University       Back Bay                 4164  4518   8682
#                         Beacon Hill              4098  4386   8484
#                         Financial District       4314  4626   8940
#                         North Station            4230  4500   8730
#                         Theatre District         4416  4758   9174
#                         West End                 4398  4764   9162
# Fenway                  Back Bay                 4212  4512   8724
#                         Beacon Hill              4200  4488   8688
#                         Financial District       4326  4590   8916
#                         North Station            4284  4686   8970
#                         Theatre District         4068  4440   8508
#                         West End                 4530  4830   9360
# Financial District      Boston University        4314  4626   8940
#                         Fenway                   4326  4602   8928
#                         Haymarket Square         4505  4824   9329
#                         North End                4152  4446   8598
#                         Northeastern University  4314  4554   8868
#                         South Station            4626  4908   9534
# Haymarket Square        Back Bay                 4236  4602   8838
#                         Beacon Hill              4218  4584   8802
#                         Financial District       4506  4824   9330
#                         North Station            4314  4560   8874
#                         Theatre District         4308  4571   8879
#                         West End                 4032  4392   8424
# North End               Back Bay                 4548  4866   9414
#                         Beacon Hill              4446  4794   9240
#                         Financial District       4152  4446   8598
#                         North Station            4194  4481   8675
#                         Theatre District         4170  4590   8760
#                         West End                 4110  4374   8484
# North Station           Boston University        4230  4500   8730
#                         Fenway                   4284  4686   8970
#                         Haymarket Square         4314  4566   8880
#                         North End                4194  4480   8674
#                         Northeastern University  4254  4650   8904
#                         South Station            4050  4368   8418
# Northeastern University Back Bay                 4266  4554   8820
#                         Beacon Hill              4302  4618   8920
#                         Financial District       4314  4560   8874
#                         North Station            4254  4650   8904
#                         Theatre District         4254  4620   8874
#                         West End                 4224  4548   8772
# South Station           Back Bay                 4224  4488   8712
#                         Beacon Hill              4200  4506   8706
#                         Financial District       4626  4908   9534
#                         North Station            4050  4374   8424
#                         Theatre District         4320  4674   8994
#                         West End                 4200  4590   8790
# Theatre District        Boston University        4416  4757   9173
#                         Fenway                   4068  4434   8502
#                         Haymarket Square         4308  4590   8898
#                         North End                4164  4596   8760
#                         Northeastern University  4254  4620   8874
#                         South Station            4320  4674   8994
# West End                Boston University        4392  4764   9156
#                         Fenway                   4530  4830   9360
#                         Haymarket Square         4032  4392   8424
#                         North End                4110  4368   8478
#                         Northeastern University  4224  4554   8778
#                         South Station            4200  4584   8784

# %% [markdown]
# # Let us drop date related features and store it in a separate dataframe.

# %%
new_df = df.drop(['id','timestamp','datetime','long_summary','apparentTemperatureHighTime','apparentTemperatureLowTime',
                  'apparentTemperatureLowTime','windGustTime','sunriseTime','sunsetTime','uvIndexTime','temperatureMinTime',
                 'temperatureMaxTime','apparentTemperatureMinTime','temperatureLowTime','apparentTemperatureMaxTime'],axis=1)

new_df.columns
# Out:
# Index(['hour', 'day', 'month', 'timezone', 'source', 'destination', 'cab_type',
#        'product_id', 'name', 'price', 'distance', 'surge_multiplier',
#        'latitude', 'longitude', 'temperature', 'apparentTemperature',
#        'short_summary', 'precipIntensity', 'precipProbability', 'humidity',
#        'windSpeed', 'windGust', 'visibility', 'temperatureHigh',
#        'temperatureHighTime', 'temperatureLow', 'apparentTemperatureHigh',
#        'apparentTemperatureLow', 'icon', 'dewPoint', 'pressure', 'windBearing',
#        'cloudCover', 'uvIndex', 'ozone', 'moonPhase', 'precipIntensityMax',
#        'temperatureMin', 'temperatureMax', 'apparentTemperatureMin',
#        'apparentTemperatureMax'],
#       dtype='object')

# %%
temp_cols= ['temperature','apparentTemperature','temperatureHigh','temperatureLow','apparentTemperatureHigh',
                'apparentTemperatureLow','temperatureMin','temperatureHighTime','temperatureMax','apparentTemperatureMin','apparentTemperatureMax','price']

# %%
df_temp = new_df[temp_cols]
df_temp.head()
# Out:
#    temperature  apparentTemperature  temperatureHigh  temperatureLow  \
# 0        42.34                37.12            43.68           34.19
# 1        43.58                37.35            47.30           42.10
# 2        38.33                32.93            47.55           33.10
# 3        34.38                29.63            45.03           28.90
# 4        37.44                30.88            42.18           36.71
#
#    apparentTemperatureHigh  apparentTemperatureLow  temperatureMin  \
# 0                    37.95                   27.39           39.89
# 1                    43.92                   36.20           40.49
# 2                    44.12                   29.11           35.36
# 3                    38.53                   26.20           34.67
# 4                    35.75                   30.29           33.10
#
#    temperatureHighTime  temperatureMax  apparentTemperatureMin  \
# 0           1544968800           43.68                   33.73
# 1           1543251600           47.30                   36.20
# 2           1543320000           47.55                   31.04
# 3           1543510800           45.03                   30.30
# 4           1543420800           42.18                   29.11
#
#    apparentTemperatureMax  price
# 0                   38.07    5.0
# 1                   43.92   11.0
# 2                   44.12    7.0
# 3                   38.53   26.0
# 4                   35.75    9.0

# %%
plt.figure(figsize=(15,20))
sns.heatmap(df_temp.corr(),annot=True,  cmap="magma")
# Out:
# <Axes: >

# %% [markdown]
# We see that all temperature related features have weak correlation with our target feature which is price,
# hence removing all of them will not make any impact to our regression model.

# %%
new_df = new_df.drop(['temperature','apparentTemperature','temperatureHigh','temperatureLow','apparentTemperatureHigh',
                'apparentTemperatureLow','temperatureMin','temperatureHighTime','temperatureMax','apparentTemperatureMin','apparentTemperatureMax'],axis=1)
new_df.shape
# Out:
# (637976, 30)

# %%
climate_column = ['precipIntensity', 'precipProbability', 'humidity', 'windSpeed',
       'windGust', 'visibility', 'dewPoint', 'pressure', 'windBearing',
       'cloudCover', 'uvIndex', 'ozone', 'moonPhase',
       'precipIntensityMax','price']
df_clim = new_df[climate_column]
df_clim.head()
# Out:
#    precipIntensity  precipProbability  humidity  windSpeed  windGust  \
# 0           0.0000                0.0      0.68       8.66      9.17
# 1           0.1299                1.0      0.94      11.98     11.98
# 2           0.0000                0.0      0.75       7.33      7.33
# 3           0.0000                0.0      0.73       5.28      5.28
# 4           0.0000                0.0      0.70       9.14      9.14
#
#    visibility  dewPoint  pressure  windBearing  cloudCover  uvIndex  ozone  \
# 0      10.000     32.70   1021.98           57        0.72        0  303.8
# 1       4.786     41.83   1003.97           90        1.00        0  291.1
# 2      10.000     31.10    992.28          240        0.03        0  315.7
# 3      10.000     26.64   1013.73          310        0.00        0  291.1
# 4      10.000     28.61    998.36          303        0.44        0  347.7
#
#    moonPhase  precipIntensityMax  price
# 0       0.30              0.1276    5.0
# 1       0.64              0.1300   11.0
# 2       0.68              0.1064    7.0
# 3       0.75              0.0000   26.0
# 4       0.72              0.0001    9.0

# %%
plt.figure(figsize=(15,20))
sns.heatmap(df_clim.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# All climate and weather related features also have weak correlation with our target feature which is price. These feature do not influence the price of the uber/lyft rides

# %%
new_df = new_df.drop(['precipIntensity', 'precipProbability', 'humidity', 'windSpeed',
       'windGust', 'visibility', 'dewPoint', 'pressure', 'windBearing',
       'cloudCover', 'uvIndex', 'ozone', 'moonPhase',
       'precipIntensityMax'],axis=1)
new_df.shape
# Out:
# (637976, 16)

# %% [markdown]
# Checking for categorical features in the dataset

# %%
category_col = new_df.select_dtypes(include=['object','category']).columns.tolist()
for column in new_df[category_col]:
    print(f'{column} : {new_df[column].unique()}')
    print()
# Out:
# timezone : ['America/New_York']
#
# source : ['Haymarket Square' 'Back Bay' 'North End' 'North Station' 'Beacon Hill'
#  'Boston University' 'Fenway' 'South Station' 'Theatre District'
#  'West End' 'Financial District' 'Northeastern University']
#
# destination : ['North Station' 'Northeastern University' 'West End' 'Haymarket Square'
#  'South Station' 'Fenway' 'Theatre District' 'Beacon Hill' 'Back Bay'
#  'North End' 'Financial District' 'Boston University']
#
# cab_type : ['Lyft' 'Uber']
#
# product_id : ['lyft_line' 'lyft_premier' 'lyft' 'lyft_luxsuv' 'lyft_plus' 'lyft_lux'
#  '6f72dfc5-27f1-42e8-84db-ccc7a75f6969'
#  '6c84fd89-3f11-4782-9b50-97c468b19529'
#  '55c66225-fbe7-4fd5-9072-eab1ece5e23e'
#  '9a0e7b09-b92b-4c41-9779-2ad22b4d779d'
#  '6d318bcc-22a3-4af6-bddd-b409bfce1546'
#  '997acbb5-e102-41e1-b155-9df7de0a73f2']
#
# name : ['Shared' 'Lux' 'Lyft' 'Lux Black XL' 'Lyft XL' 'Lux Black' 'UberXL'
#  'Black' 'UberX' 'WAV' 'Black SUV' 'UberPool']
#
# short_summary : [' Mostly Cloudy ' ' Rain ' ' Clear ' ' Partly Cloudy ' ' Overcast '
#  ' Light Rain ' ' Foggy ' ' Possible Drizzle ' ' Drizzle ']
#
# icon : [' partly-cloudy-night ' ' rain ' ' clear-night ' ' cloudy ' ' fog '
#  ' clear-day ' ' partly-cloudy-day ']

# %% [markdown]
# We can see that 'timezone' feature has only 1 value and 'product_id' feature contains many unidentified values. So we can remove or drop them.

# %%
new_df = new_df.drop(['timezone','product_id'],axis=1)

# %%
new_df.columns
# Out:
# Index(['hour', 'day', 'month', 'source', 'destination', 'cab_type', 'name',
#        'price', 'distance', 'surge_multiplier', 'latitude', 'longitude',
#        'short_summary', 'icon'],
#       dtype='object')

# %% [markdown]
# Fourth, i want to check the correlation of our categorical features with our target feature (price)

# %%
new_cat = ['source',
 'destination',
 'cab_type',
 'name',
 'short_summary',
 'icon','price']

df_cat = new_df[new_cat]
df_cat.head()
# Out:
#              source    destination cab_type          name    short_summary  \
# 0  Haymarket Square  North Station     Lyft        Shared   Mostly Cloudy
# 1  Haymarket Square  North Station     Lyft           Lux            Rain
# 2  Haymarket Square  North Station     Lyft          Lyft           Clear
# 3  Haymarket Square  North Station     Lyft  Lux Black XL           Clear
# 4  Haymarket Square  North Station     Lyft       Lyft XL   Partly Cloudy
#
#                     icon  price
# 0   partly-cloudy-night     5.0
# 1                  rain    11.0
# 2           clear-night     7.0
# 3           clear-night    26.0
# 4   partly-cloudy-night     9.0

# %% [markdown]
# Convert to these categorical columns to one-hot encoding

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

df_cat_encode= df_cat.copy()
for col in df_cat_encode.select_dtypes(include='O').columns:
    df_cat_encode[col]=le.fit_transform(df_cat_encode[col])


df_cat_encode
# Out:
#         source  destination  cab_type  name  short_summary  icon  price
# 0            5            7         0     7              4     5    5.0
# 1            5            7         0     2              8     6   11.0
# 2            5            7         0     5              0     1    7.0
# 3            5            7         0     4              0     1   26.0
# 4            5            7         0     6              6     5    9.0
# ...        ...          ...       ...   ...            ...   ...    ...
# 693065      11            6         1    11              6     5    9.5
# 693066      11            6         1    10              6     5   13.0
# 693067      11            6         1     9              6     5    9.5
# 693069      11            6         1     1              6     5   27.0
# 693070      11            6         1     8              6     5   10.0
#
# [637976 rows x 7 columns]

# %%
plt.style.use("fivethirtyeight")

# %%
plt.figure(figsize=(15,20))
sns.heatmap(df_cat_encode.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# We can see only name feature that has a relatively strong correlation. Source,destination, and cab_type features have relatively weak correlation, but i will pick cab_type feature because it has stronger correlation than other two features. I will drop or remove the rest of the columns

# %%
new_df.head()
# Out:
#    hour  day  month            source    destination cab_type          name  \
# 0     9   16     12  Haymarket Square  North Station     Lyft        Shared
# 1     2   27     11  Haymarket Square  North Station     Lyft           Lux
# 2     1   28     11  Haymarket Square  North Station     Lyft          Lyft
# 3     4   30     11  Haymarket Square  North Station     Lyft  Lux Black XL
# 4     3   29     11  Haymarket Square  North Station     Lyft       Lyft XL
#
#    price  distance  surge_multiplier  latitude  longitude    short_summary  \
# 0    5.0      0.44               1.0   42.2148    -71.033   Mostly Cloudy
# 1   11.0      0.44               1.0   42.2148    -71.033            Rain
# 2    7.0      0.44               1.0   42.2148    -71.033           Clear
# 3   26.0      0.44               1.0   42.2148    -71.033           Clear
# 4    9.0      0.44               1.0   42.2148    -71.033   Partly Cloudy
#
#                     icon
# 0   partly-cloudy-night
# 1                  rain
# 2           clear-night
# 3           clear-night
# 4   partly-cloudy-night

# %%
new_exxpl = ['hour',
 'day', 'month',
 'cab_type',
 'name',
 'price']

df_exxpl = new_df[new_exxpl]
df_exxpl.head()

df_exxpl_encode= df_exxpl.copy()
for col in df_exxpl_encode.select_dtypes(include='O').columns:
    df_exxpl_encode[col]=le.fit_transform(df_exxpl_encode[col])

# %%
plt.figure(figsize=(15,20))

sns.heatmap(df_exxpl_encode.corr(),annot=True )
# Out:
# <Axes: >

# %% [markdown]
# Also i will remove hour, day, month, latitude, longitude, because we won't need them for now

# %%
new_df = new_df.drop(['hour','day','month','latitude','longitude'],axis=1)
new_df.head()
# Out:
#              source    destination cab_type          name  price  distance  \
# 0  Haymarket Square  North Station     Lyft        Shared    5.0      0.44
# 1  Haymarket Square  North Station     Lyft           Lux   11.0      0.44
# 2  Haymarket Square  North Station     Lyft          Lyft    7.0      0.44
# 3  Haymarket Square  North Station     Lyft  Lux Black XL   26.0      0.44
# 4  Haymarket Square  North Station     Lyft       Lyft XL    9.0      0.44
#
#    surge_multiplier    short_summary                   icon
# 0               1.0   Mostly Cloudy    partly-cloudy-night
# 1               1.0            Rain                   rain
# 2               1.0           Clear            clear-night
# 3               1.0           Clear            clear-night
# 4               1.0   Partly Cloudy    partly-cloudy-night

# %%
new_df.columns
# Out:
# Index(['source', 'destination', 'cab_type', 'name', 'price', 'distance',
#        'surge_multiplier', 'short_summary', 'icon'],
#       dtype='object')

# %% [markdown]
# #### Removing Outliers using IQR method for checking top and bottom outliers

# %%
Qp12 = new_df['price'].quantile(0.25)
Qp32 = new_df['price'].quantile(0.75)


IQRp = Qp32-Qp12
print("Qp12 ", Qp12)
print("Qp32 ", Qp32)
print("IQRp ", IQRp)


new_df
# Out:
# Qp12  9.0
# Qp32  22.5
# IQRp  13.5
#                   source    destination cab_type          name  price  \
# 0       Haymarket Square  North Station     Lyft        Shared    5.0
# 1       Haymarket Square  North Station     Lyft           Lux   11.0
# 2       Haymarket Square  North Station     Lyft          Lyft    7.0
# 3       Haymarket Square  North Station     Lyft  Lux Black XL   26.0
# 4       Haymarket Square  North Station     Lyft       Lyft XL    9.0
# ...                  ...            ...      ...           ...    ...
# 693065          West End      North End     Uber           WAV    9.5
# 693066          West End      North End     Uber        UberXL   13.0
# 693067          West End      North End     Uber         UberX    9.5
# 693069          West End      North End     Uber     Black SUV   27.0
# 693070          West End      North End     Uber      UberPool   10.0
#
#         distance  surge_multiplier    short_summary                   icon
# 0           0.44               1.0   Mostly Cloudy    partly-cloudy-night
# 1           0.44               1.0            Rain                   rain
# 2           0.44               1.0           Clear            clear-night
# 3           0.44               1.0           Clear            clear-night
# 4           0.44               1.0   Partly Cloudy    partly-cloudy-night
# ...          ...               ...              ...                    ...
# 693065      1.00               1.0   Partly Cloudy    partly-cloudy-night
# 693066      1.00               1.0   Partly Cloudy    partly-cloudy-night
# 693067      1.00               1.0   Partly Cloudy    partly-cloudy-night
# 693069      1.00               1.0   Partly Cloudy    partly-cloudy-night
# 693070      1.00               1.0   Partly Cloudy    partly-cloudy-night
#
# [637976 rows x 9 columns]

# %%
new_df[new_df['price']>(Qp32+(1.5*IQRp))]
# Out:
#                     source        destination cab_type          name  price  \
# 706          South Station           Back Bay     Lyft     Lux Black   52.5
# 707          South Station           Back Bay     Lyft  Lux Black XL   67.5
# 769       Theatre District  Boston University     Lyft  Lux Black XL   45.5
# 1094      Theatre District             Fenway     Lyft  Lux Black XL   45.5
# 1318    Financial District  Boston University     Lyft  Lux Black XL   45.5
# ...                    ...                ...      ...           ...    ...
# 692439  Financial District  Boston University     Uber     Black SUV   47.0
# 692698  Financial District             Fenway     Lyft  Lux Black XL   52.5
# 692891  Financial District  Boston University     Lyft  Lux Black XL   47.5
# 692962            Back Bay          North End     Uber     Black SUV   51.0
# 693007            Back Bay          North End     Uber     Black SUV   49.5
#
#         distance  surge_multiplier    short_summary                   icon
# 706         3.25              2.00   Partly Cloudy    partly-cloudy-night
# 707         3.25              2.00   Partly Cloudy    partly-cloudy-night
# 769         4.76              1.00   Partly Cloudy      partly-cloudy-day
# 1094        4.31              1.00      Light Rain                   rain
# 1318        5.33              1.00        Overcast                 cloudy
# ...          ...               ...              ...                    ...
# 692439      5.56              1.00   Mostly Cloudy      partly-cloudy-day
# 692698      4.58              1.25   Partly Cloudy    partly-cloudy-night
# 692891      5.42              1.00           Foggy                    fog
# 692962      7.36              1.00   Mostly Cloudy    partly-cloudy-night
# 693007      7.36              1.00   Mostly Cloudy      partly-cloudy-day
#
# [5589 rows x 9 columns]

# %%
new_df[new_df['price']<(Qp12-(1.5*IQRp))]
# Out:
# Empty DataFrame
# Columns: [source, destination, cab_type, name, price, distance, surge_multiplier, short_summary, icon]
# Index: []

# %%
print('Size before removing :',new_df.shape)
new_df= new_df[~((new_df['price']>(Qp32+(1.5*IQRp))))]
print('Size after removing :',new_df.shape)
# Out:
# Size before removing : (637976, 9)
# Size after removing : (632387, 9)

# %%
def one_hot_encoder(data,feature,keep_first=True):

    one_hot_cols = pd.get_dummies(data[feature])

    for col in one_hot_cols.columns:
        one_hot_cols.rename({col:f'{feature}_'+col},axis=1,inplace=True)

    new_data = pd.concat([data,one_hot_cols],axis=1)
    new_data.drop(feature,axis=1,inplace=True)

    if keep_first == False:
        new_data=new_data.iloc[:,1:]

    return new_data

# %%
new_df_onehot=new_df.copy()
for col in new_df_onehot.select_dtypes(include = 'O').columns:
    new_df_onehot=one_hot_encoder(new_df_onehot,col)

new_df_onehot.head()


# new_df['cab_type'].unique().sum()


# from sklearn.preprocessing import OneHotEncoder

# enc = OneHotEncoder(handle_unknown='ignore', sparse_output=False).set_output(transform="pandas")
# data = enc.fit_transform(new_df[['cab_type','name']])
# Out:
#    price  distance  surge_multiplier  source_Back Bay  source_Beacon Hill  \
# 0    5.0      0.44               1.0            False               False
# 1   11.0      0.44               1.0            False               False
# 2    7.0      0.44               1.0            False               False
# 3   26.0      0.44               1.0            False               False
# 4    9.0      0.44               1.0            False               False
#
#    source_Boston University  source_Fenway  source_Financial District  \
# 0                     False          False                      False
# 1                     False          False                      False
# 2                     False          False                      False
# 3                     False          False                      False
# 4                     False          False                      False
#
#    source_Haymarket Square  source_North End  ...  \
# 0                     True             False  ...
# 1                     True             False  ...
# 2                     True             False  ...
# 3                     True             False  ...
# 4                     True             False  ...
#
#    short_summary_ Partly Cloudy   short_summary_ Possible Drizzle   \
# 0                          False                             False
# 1                          False                             False
# 2                          False                             False
# 3                          False                             False
# 4                           True                             False
#
#    short_summary_ Rain   icon_ clear-day   icon_ clear-night   icon_ cloudy   \
# 0                 False             False               False          False
# 1                  True             False               False          False
# 2                 False             False                True          False
# 3                 False             False                True          False
# 4                 False             False               False          False
#
#    icon_ fog   icon_ partly-cloudy-day   icon_ partly-cloudy-night   \
# 0       False                     False                        True
# 1       False                     False                       False
# 2       False                     False                       False
# 3       False                     False                       False
# 4       False                     False                        True
#
#    icon_ rain
# 0        False
# 1         True
# 2        False
# 3        False
# 4        False
#
# [5 rows x 57 columns]

# %%
x = new_df_onehot.drop(columns=['price'],axis=1).values
y = new_df_onehot['price']

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)
new_df_onehot
# Out:
#         price  distance  surge_multiplier  source_Back Bay  \
# 0         5.0      0.44               1.0            False
# 1        11.0      0.44               1.0            False
# 2         7.0      0.44               1.0            False
# 3        26.0      0.44               1.0            False
# 4         9.0      0.44               1.0            False
# ...       ...       ...               ...              ...
# 693065    9.5      1.00               1.0            False
# 693066   13.0      1.00               1.0            False
# 693067    9.5      1.00               1.0            False
# 693069   27.0      1.00               1.0            False
# 693070   10.0      1.00               1.0            False
#
#         source_Beacon Hill  source_Boston University  source_Fenway  \
# 0                    False                     False          False
# 1                    False                     False          False
# 2                    False                     False          False
# 3                    False                     False          False
# 4                    False                     False          False
# ...                    ...                       ...            ...
# 693065               False                     False          False
# 693066               False                     False          False
# 693067               False                     False          False
# 693069               False                     False          False
# 693070               False                     False          False
#
#         source_Financial District  source_Haymarket Square  source_North End  \
# 0                           False                     True             False
# 1                           False                     True             False
# 2                           False                     True             False
# 3                           False                     True             False
# 4                           False                     True             False
# ...                           ...                      ...               ...
# 693065                      False                    False             False
# 693066                      False                    False             False
# 693067                      False                    False             False
# 693069                      False                    False             False
# 693070                      False                    False             False
#
#         ...  short_summary_ Partly Cloudy   short_summary_ Possible Drizzle   \
# 0       ...                          False                             False
# 1       ...                          False                             False
# 2       ...                          False                             False
# 3       ...                          False                             False
# 4       ...                           True                             False
# ...     ...                            ...                               ...
# 693065  ...                           True                             False
# 693066  ...                           True                             False
# 693067  ...                           True                             False
# 693069  ...                           True                             False
# 693070  ...                           True                             False
#
#         short_summary_ Rain   icon_ clear-day   icon_ clear-night   \
# 0                      False             False               False
# 1                       True             False               False
# 2                      False             False                True
# 3                      False             False                True
# 4                      False             False               False
# ...                      ...               ...                 ...
# 693065                 False             False               False
# 693066                 False             False               False
# 693067                 False             False               False
# 693069                 False             False               False
# 693070                 False             False               False
#
#         icon_ cloudy   icon_ fog   icon_ partly-cloudy-day   \
# 0               False       False                     False
# 1               False       False                     False
# 2               False       False                     False
# 3               False       False                     False
# 4               False       False                     False
# ...               ...         ...                       ...
# 693065          False       False                     False
# 693066          False       False                     False
# 693067          False       False                     False
# 693069          False       False                     False
# 693070          False       False                     False
#
#         icon_ partly-cloudy-night   icon_ rain
# 0                             True        False
# 1                            False         True
# 2                            False        False
# 3                            False        False
# 4                             True        False
# ...                            ...          ...
# 693065                        True        False
# 693066                        True        False
# 693067                        True        False
# 693069                        True        False
# 693070                        True        False
#
# [632387 rows x 57 columns]

# %% [markdown]
# Creating the model on the basis of features chosen using VIF

# %%
#Selected the data based on the VIF values

vif_data
print("vif shape", vif_data.shape) #NOTE: This is a data without outliers so we will not need to remove the outliers


#Converting the data to one hot encoding
vif_data_onehot=vif_data.copy()
vif_data_onehot.dtypes
for col in vif_data_onehot.select_dtypes(include = 'object').columns:
    vif_data_onehot =one_hot_encoder(vif_data_onehot,col)

#diffrentiate between the x and y
x_vif = vif_data_onehot.drop(columns=['price'],axis=1).values
y_vif = vif_data_onehot['price']

#dividing into test and train model
X_train_vif, X_test_vif, y_train_vif, y_test_vif = train_test_split(x_vif, y_vif, test_size=0.3, random_state=0)
new_df_onehot

# fitting the regression model
reg_vif = LinearRegression()
model_vif = reg_vif.fit(X_train_vif,y_train_vif)
y_pred_vif = model_vif.predict(X_test_vif)

print("R2 score: ", str(r2_score(y_test_vif, y_pred_vif)))
# Out:
# vif shape (637976, 11)
# R2 score:  0.9281050176599771

# %% [markdown]
# The R2

# %% [markdown]
# ## Running bootstrap for linear regression using resampling the data
#
#
# ```
# # This is formatted as code
# ```

# %%
# Initialize the models
lasso = Lasso(alpha=0.1)
ridge = Ridge(alpha=0.1)
decision_tree = DecisionTreeRegressor(random_state=42)
linear = LinearRegression()

# Fit the models
lasso.fit(X_train, y_train)
ridge.fit(X_train, y_train)
decision_tree.fit(X_train, y_train)
linear.fit(X_train,y_train)


# Predict on the test set
y_pred_lasso = lasso.predict(X_test)
y_pred_ridge = ridge.predict(X_test)
y_pred_decision_tree = decision_tree.predict(X_test)
y_pred_linear = decision_tree.predict(X_test)


y_red_tests  = [y_pred_lasso, y_pred_ridge, y_pred_decision_tree, y_pred_linear]

# Calculate the performance metrics for each model
mse_lasso = mean_squared_error(y_test, y_pred_lasso)
r2_lasso = r2_score(y_test, y_pred_lasso)

mse_ridge = mean_squared_error(y_test, y_pred_ridge)
r2_ridge = r2_score(y_test, y_pred_ridge)

mse_decision_tree = mean_squared_error(y_test, y_pred_decision_tree)
r2_decision_tree = r2_score(y_test, y_pred_decision_tree)


mse_linear = mean_squared_error(y_test, y_pred_linear)
r2_linear = r2_score(y_test, y_pred_linear)

# Output the performance metrics for each model
performance_metrics = {
    'Lasso': {'MSE': mse_lasso, 'R2': r2_lasso},
    'Ridge': {'MSE': mse_ridge, 'R2': r2_ridge},
    'Decision Tree': {'MSE': mse_decision_tree, 'R2': r2_decision_tree},
    'Linear': {'MSE': mse_linear, 'R2': r2_linear}
}



names = ["Lasso", "Ridge", "Decision tree","Linear"]
for i, (name, test) in enumerate(zip(names, y_red_tests)):
  # with plt.style.context("dark_background"):
    probplot(test, dist='norm', plot=plt)
    plt.title(f'QQ Plot of Residuals using {name}')
    plt.show()

# %%
bootstrap_regressor = BaggingRegressor(DecisionTreeRegressor(), n_estimators=100, random_state=42)

# Fit the model on the training data
bootstrap_regressor.fit(X_train, y_train)

# Make predictions on the test data
y_pred = bootstrap_regressor.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error: {mse}')
# Out:
# Mean Squared Error: 2.6057951840130977

# %%
r2_bootstrap = r2_score(y_test, y_pred)
r2_bootstrap
# Out:
# 0.9662205033317965

# %%
xgb_model = XGBRegressor()

kfold =KFold(n_splits=5)

# %%
tuning_params = {
"n_estimators": [x for x in range(50, 400, 50)],
"max_depth": [3,6,9],
"gamma": [0.01, .1],
"learning_rate": [.001, .01, .1, 1]
}

# %%
GS = GridSearchCV(estimator = xgb_model, param_grid = tuning_params, scoring = "r2", cv=5, refit= "r2", verbose= 4)

# %%
GS.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 168 candidates, totalling 840 fits
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=50;, score=0.059 total time=   0.9s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=50;, score=0.059 total time=   0.7s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=50;, score=0.059 total time=   0.7s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=50;, score=0.059 total time=   0.7s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=50;, score=0.059 total time=   0.7s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=100;, score=0.113 total time=   0.9s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=100;, score=0.113 total time=   0.9s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=100;, score=0.113 total time=   0.9s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=100;, score=0

# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=350;, score=0.967 total time=   1.8s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=350;, score=0.968 total time=   1.8s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=350;, score=0.967 total time=   1.8s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=350;, score=0.968 total time=   1.8s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=350;, score=0.967 total time=   1.8s
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=50;, score=0.967 total time=   0.8s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=50;, score=0.968 total time=   0.8s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=50;, score=0.967 total time=   0.8s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=50;, score=0.968 total time=   0.8s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=50;, score=0.967 total time=   0.8s
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=100;, score=0.968 total time=   1.1s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=100;, score=0.968 total time=   1.1s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=100;, score=0.967 total time=   1.1s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=100;, score=0.968 total time=   1.1s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=100;, score=0.968 total time=   1.1s
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=150;, score=0.968 total time=   1.3s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=150;, score=0.968 total time=   1.4s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=150;, score=0.968 total time=   1.4s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=150;, score=0.968 total time=   1.3s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=150;, score=0.968 total time=   1.3s
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=200;, score=0.968 total time=   1.6s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=200;, score=0.968 total time=   1.6s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=200;, score=0.967 total time=   1.6s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=200;, score=0.968 total time=   1.6s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=200;, score=0.968 total time=   1.6s
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=250;, score=0.968 total time=   1.8s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=250;, score=0.968 total time=   1.8s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=250;, score=0.967 total time=   1.9s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=250;, score=0.968 total time=   1.9s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=250;, score=0.968 total time=   1.9s
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=300;, score=0.968 total time=   2.1s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=300;, score=0.968 total time=   2.1s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=300;, score=0.967 total time=   2.1s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=300;, score=0.968 total time=   2.1s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=300;, score=0.968 total time=   2.1s
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=350;, score=0.968 total time=   2.3s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=350;, score=0.967 total time=   2.3s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=350;, score=0.967 total time=   2.3s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=350;, score=0.967 total time=   2.4s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=350;, score=0.967 total time=   2.3s
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=50;, score=0.967 total time=   1.0s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=50;, score=0.967 total time=   1.0s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=50;, score=0.967 total time=   1.0s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=50;, score=0.967 total time=   1.0s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=50;, score=0.967 total time=   0.9s
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=100;, score=0.966 total time=   1.3s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=100;, score=0.967 total time=   1.2s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=100;, score=0.966 total time=   1.3s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=100;, score=0.966 total time=   1.3s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=100;, score=0.966 total time=   1.3s
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=150;, score=0.966 total time=   1.5s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=150;, score=0.967 total time=   1.3s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=150;, score=0.966 total time=   1.5s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=150;, score=0.966 total time=   1.5s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=150;, score=0.966 total time=   1.4s
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=200;, score=0.966 total time=   1.6s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=200;, score=0.967 total time=   1.4s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=200;, score=0.966 total time=   1.6s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=200;, score=0.966 total time=   1.6s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=200;, score=0.966 total time=   1.6s
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=250;, score=0.966 total time=   1.7s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=250;, score=0.967 total time=   1.5s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=250;, score=0.966 total time=   1.7s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=250;, score=0.966 total time=   1.7s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=250;, score=0.966 total time=   1.7s
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=300;, score=0.966 total time=   1.9s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=300;, score=0.967 total time=   1.7s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=300;, score=0.966 total time=   1.8s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=300;, score=0.966 total time=   1.8s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=300;, score=0.966 total time=   1.8s
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=350;, score=0.966 total time=   2.0s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=350;, score=0.967 total time=   1.8s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=350;, score=0.966 total time=   2.0s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=350;, score=0.966 total time=   1.9s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=350;, score=0.966 total time=   1.9s
# GridSearchCV(cv=5,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, feature_weights=None,
#                                     gamma=None, grow_policy=None,
#                                     importance_type=None,
#                                     interaction_constraints=None...
#                                     max_cat_to_onehot=None, max_delta_step=None,
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None,
#                                     multi_strategy=None, n_estimators=None,
#                                     n_jobs=None, num_parallel_tree=None, ...),
#              param_grid={'gamma': [0.01, 0.1],
#                          'learning_rate': [0.001, 0.01, 0.1, 1],
#                          'max_depth': [3, 6, 9],
#                          'n_estimators': [50, 100, 150, 200, 250, 300, 350]},
#              refit='r2', scoring='r2', verbose=4)

# %%
print(GS.best_estimator_)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=0.01, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=9,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=350,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
### Finding the best paramters of our Grid Model
print(GS.best_params_)
# Out:
# {'gamma': 0.01, 'learning_rate': 0.1, 'max_depth': 9, 'n_estimators': 350}

# %%
print(GS.best_score_)
# Out:
# 0.9688223374266183

# %%
gs_y_test = GS.predict(X_test)
gs_y_mse = mean_squared_error(y_test, gs_y_test)
gs_y_mse #estimating the mean sqaured error of Grid Search Fit
# Out:
# 2.3644308832460816

# %%
r2_gsv = r2_score(y_test, gs_y_test)
r2_gsv #estimating the accuracy of our model
# Out:
# 0.9693493619019572
